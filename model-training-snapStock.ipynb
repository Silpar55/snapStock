# %%
# Importing ultralytics for YOLO
# !pip install ultralytics

# %%
# Checking if we are using T4 GPU
# !nvidia-smi

# %%
# Checking if torch recognize the GPU
import torch

print(f"CUDA available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA device count: {torch.cuda.device_count()}")
    print(f"Device name: {torch.cuda.get_device_name(0)}")

# %%
# Follow the steps in case Torch does not recognize the GPU

# 1. Uninstall existing PyTorch versions for a clean slate
# !pip uninstall -y torch torchvision torchaudio

# 2. Install the correct PyTorch version with CUDA 12.1 support
#    This is the official command from the PyTorch website.
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# 3. Reinstall ultralytics to link with the new PyTorch version
# !pip install ultralytics

# %%
from ultralytics import YOLO

# # Load a model
# model = YOLO("yolo11m.pt")

# Load 25_epochs model to continue training
model = YOLO('./drive/MyDrive/models/25_epoch/weights/last.pt')

# Train model
results = model.train(data='./drive/MyDrive/dataset/Bakery-Detection/data.yaml', project='./drive/MyDrive/models', name='50_epoch', device='gpu', epochs=25, imgsz=640, batch=16)

# %%
# Download the .zip file from github, unzip it and put it in your google drive
# !unzip -q ./drive/MyDrive/Bakery-Detection.zip -d ./drive/MyDrive/dataset/
